# %%
# importing libraries
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("loan_train.csv")

# %%
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail(5)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 508  LP002626    Male     Yes          0      Graduate           Yes
# 509  LP002634  Female      No          1      Graduate            No
# 510  LP002637    Male      No          0  Not Graduate            No
# 511  LP002640    Male     Yes          1      Graduate            No
# 512  LP002643    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 508             2479             3013.0       188.0             360.0
# 509            13262                0.0        40.0             360.0
# 510             3598             1287.0       100.0             360.0
# 511             6065             2004.0       250.0             360.0
# 512             3283             2035.0       148.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 508             1.0         Urban           Y
# ...

# %%
df.shape
# Out:
# (513, 13)

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            513 non-null    object
#  1   Gender             503 non-null    object
#  2   Married            510 non-null    object
#  3   Dependents         501 non-null    object
#  4   Education          513 non-null    object
#  5   Self_Employed      486 non-null    object
#  6   ApplicantIncome    513 non-null    int64
#  7   CoapplicantIncome  513 non-null    float64
#  8   LoanAmount         495 non-null    float64
#  9   Loan_Amount_Term   499 non-null    float64
#  10  Credit_History     470 non-null    float64
#  11  Property_Area      513 non-null    object
#  12  Loan_Status        513 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 52.2+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               10
# Married               3
# Dependents           12
# Education             0
# Self_Employed        27
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           18
# Loan_Amount_Term     14
# Credit_History       43
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 127

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       513.000000         513.000000  495.000000        499.000000
# mean       5497.013645        1537.364366  144.739394        343.118236
# std        6486.147388        2144.079038   83.200278         63.375911
# min         150.000000           0.000000   17.000000         12.000000
# 25%        2876.000000           0.000000  100.000000        360.000000
# 50%        3846.000000        1210.000000  127.000000        360.000000
# 75%        5746.000000        2283.000000  163.000000        360.000000
# max       81000.000000       20000.000000  700.000000        480.000000
#
#        Credit_History
# count      470.000000
# mean         0.846809
# std          0.360556
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# Visualizing categorical features
plt.figure(1)
plt.subplot(221)
df['Gender'].value_counts(normalize=True).plot.bar(figsize=(20,10), title= 'Gender')

plt.subplot(222)
df['Married'].value_counts(normalize=True).plot.bar(title= 'Married')

plt.subplot(223)
df['Dependents'].value_counts(normalize=True).plot.bar(title= 'Dependents')

plt.subplot(224)
df['Education'].value_counts(normalize=True).plot.bar(title= 'Education')

plt.show()

# %% [markdown]
# we can see that around 81% were male applicants and around 66% were married again most of the applicants didn't have any dependents , lastly around 78% applicants are graduate

# %%
# Visualizing numerical features to see outliers
plt.figure(1)
plt.subplot(121)
sns.distplot(df['ApplicantIncome']);

plt.subplot(122)
df['ApplicantIncome'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(1)
plt.subplot(121)
sns.distplot(df['CoapplicantIncome']);

plt.subplot(122)
df['CoapplicantIncome'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(1)
plt.subplot(121)
df=df.dropna()
sns.distplot(df['LoanAmount']);

plt.subplot(122)
df['LoanAmount'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(1)
plt.subplot(121)
df=df.dropna()
sns.distplot(df['Credit_History']);

plt.subplot(122)
df['Credit_History'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(1)
plt.subplot(121)
df=df.dropna()
sns.distplot(df['Loan_Amount_Term']);

plt.subplot(122)
df['Loan_Amount_Term'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       400.000000         400.000000  400.000000        400.000000
# mean       5396.627500        1557.692300  142.517500        343.500000
# std        5973.412452        2260.853166   75.693484         62.436976
# min         150.000000           0.000000   17.000000         36.000000
# 25%        2887.250000           0.000000  100.000000        360.000000
# 50%        3871.000000        1146.500000  127.500000        360.000000
# 75%        5823.000000        2253.250000  165.250000        360.000000
# max       81000.000000       20000.000000  600.000000        480.000000
#
#        Credit_History
# count      400.000000
# mean         0.855000
# std          0.352542
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# ## missing value detection and removal

# %%
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0])
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mode()[0])
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %%
# Drop rows which contain any NaN value in the selected columns


df1 = df.dropna( how='any',
                    subset=['Gender','Married','Self_Employed','Dependents'])

# %%
df1.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df1.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       400.000000         400.000000  400.000000        400.000000
# mean       5396.627500        1557.692300  142.517500        343.500000
# std        5973.412452        2260.853166   75.693484         62.436976
# min         150.000000           0.000000   17.000000         36.000000
# 25%        2887.250000           0.000000  100.000000        360.000000
# 50%        3871.000000        1146.500000  127.500000        360.000000
# 75%        5823.000000        2253.250000  165.250000        360.000000
# max       81000.000000       20000.000000  600.000000        480.000000
#
#        Credit_History
# count      400.000000
# mean         0.855000
# std          0.352542
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# ## outliers removal and detection

# %%
#1
print("Highest allowed",df1['CoapplicantIncome'].mean() + 3*df1['CoapplicantIncome'].std())
print("Lowest allowed",df1['CoapplicantIncome'].mean() - 3*df1['CoapplicantIncome'].std())
# Out:
# Highest allowed 8340.251797418498
# Lowest allowed -5224.867197475298

# %%
#2
#Finding the Outliers
df1[(df1['CoapplicantIncome'] > 8178.533461092219) | (df1['CoapplicantIncome'] < -5047.020874934288)]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9    LP001020    Male     Yes          1  Graduate            No
# 122  LP001431  Female      No          0  Graduate            No
# 177  LP001610    Male     Yes         3+  Graduate            No
# 402  LP002297    Male      No          0  Graduate            No
# 417  LP002342    Male     Yes          2  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 9              12841            10968.0       349.0             360.0
# 122             2137             8980.0       137.0             360.0
# 177             5516            11300.0       495.0             360.0
# 402             2500            20000.0       103.0             360.0
# 417             1600            20000.0       239.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 9               1.0     Semiurban           N
# 122             0.0     Semiurban           Y
# ...

# %%
#3
#Trimming of Outliers

df2 = df1[(df1['CoapplicantIncome'] < 8178.533461092219) & (df1['Loan_Amount_Term'] > -5047.020874934288)]
df2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 508  LP002626    Male     Yes          0      Graduate           Yes
# 509  LP002634  Female      No          1      Graduate            No
# 510  LP002637    Male      No          0  Not Graduate            No
# 511  LP002640    Male     Yes          1      Graduate            No
# 512  LP002643    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#4
#Capping on Outliers

upper_limit = df2['CoapplicantIncome'].mean() + 3*df2['CoapplicantIncome'].std()
lower_limit = df2['CoapplicantIncome'].mean() - 3*df2['CoapplicantIncome'].std()

# %%
#5
#Now, apply the Capping

df2['CoapplicantIncome'] = np.where(
    df2['CoapplicantIncome']>upper_limit,
    upper_limit,
    np.where(
        df2['CoapplicantIncome']<lower_limit,
        lower_limit,
        df2['CoapplicantIncome']
    )
)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_5472/1946998003.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['CoapplicantIncome'] = np.where(

# %%
plt.figure(1)
plt.subplot(121)
sns.distplot(df['CoapplicantIncome']);

plt.subplot(122)
df['CoapplicantIncome'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#7
#df['CoapplicantIncome'].describe()
plt.figure(1)
plt.subplot(121)
sns.distplot(df2['CoapplicantIncome']);

plt.subplot(122)
df2['CoapplicantIncome'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#1
print("Highest allowed",df2['ApplicantIncome'].mean() + 3*df2['ApplicantIncome'].std())
print("Lowest allowed",df2['ApplicantIncome'].mean() - 3*df2['ApplicantIncome'].std())
# Out:
# Highest allowed 23379.884544695044
# Lowest allowed -12574.532645960864

# %%
#2
#Finding the Outliers
df2[(df2['ApplicantIncome'] > 23316.864855456075) | (df2['ApplicantIncome'] < -12523.609855456078)]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 155  LP001536   Male     Yes         3+  Graduate            No
# 183  LP001637   Male     Yes          1  Graduate            No
# 185  LP001640   Male     Yes          0  Graduate           Yes
# 409  LP002317   Male     Yes         3+  Graduate            No
# 443  LP002422   Male      No          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 155            39999                0.0       600.0             180.0
# 183            33846                0.0       260.0             360.0
# 185            39147             4750.0       120.0             360.0
# 409            81000                0.0       360.0             360.0
# 443            37719                0.0       152.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 155             0.0     Semiurban           Y
# 183             1.0     Semiurban           N
# ...

# %%
#3
#Trimming of Outliers

df3 = df2[(df2['ApplicantIncome'] < 23316.864855456075) & (df2['ApplicantIncome'] > -12523.609855456078)]
df3
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 508  LP002626    Male     Yes          0      Graduate           Yes
# 509  LP002634  Female      No          1      Graduate            No
# 510  LP002637    Male      No          0  Not Graduate            No
# 511  LP002640    Male     Yes          1      Graduate            No
# 512  LP002643    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#4
#Capping on Outliers

upper_limit = df3['ApplicantIncome'].mean() + 3*df3['ApplicantIncome'].std()
lower_limit = df3['ApplicantIncome'].mean() - 3*df3['ApplicantIncome'].std()

# %%
#5
#Now, apply the Capping

df3['ApplicantIncome'] = np.where(
    df3['ApplicantIncome']>upper_limit,
    upper_limit,
    np.where(
        df3['ApplicantIncome']<lower_limit,
        lower_limit,
        df3['ApplicantIncome']
    )
)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_5472/3290002802.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['ApplicantIncome'] = np.where(

# %%
#6 Visualizing numerical features to see outliers
plt.figure(1)
plt.subplot(121)
sns.distplot(df['ApplicantIncome']);

plt.subplot(122)
df['ApplicantIncome'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#7 Visualizing numerical features to see outliers
plt.figure(1)
plt.subplot(121)
sns.distplot(df3['ApplicantIncome']);

plt.subplot(122)
df3['ApplicantIncome'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#1
print("Highest allowed",df3['LoanAmount'].mean() + 3*df3['LoanAmount'].std())
print("Lowest allowed",df3['LoanAmount'].mean() - 3*df3['LoanAmount'].std())
# Out:
# Highest allowed 344.8512207148091
# Lowest allowed -66.94352840711676

# %%
#2
#Finding the Outliers
df3[(df3['LoanAmount'] > 369.59795065885476) | (df3['LoanAmount'] < -84.5629506588547)]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 278  LP001907   Male     Yes          0  Graduate            No
# 308  LP001996   Male      No          0  Graduate            No
# 325  LP002067   Male     Yes          1  Graduate           Yes
# 369  LP002191   Male     Yes          0  Graduate            No
# 372  LP002201   Male     Yes          2  Graduate           Yes
# 487  LP002547   Male     Yes          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 278     14583.000000           0.000000       436.0             360.0
# 308     14660.909263           0.000000       480.0             360.0
# 325      8666.000000        4983.000000       376.0             360.0
# 369     14660.909263        5266.000000       570.0             360.0
# 372      9323.000000        6433.535128       380.0             300.0
# 487     14660.909263           0.000000       500.0             360.0
#
# ...

# %%
#3
#Trimming of Outliers

df4 = df3[(df3['LoanAmount'] < 369.59795065885476) & (df3['LoanAmount'] > -84.5629506588547)]
df4
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 508  LP002626    Male     Yes          0      Graduate           Yes
# 509  LP002634  Female      No          1      Graduate            No
# 510  LP002637    Male      No          0  Not Graduate            No
# 511  LP002640    Male     Yes          1      Graduate            No
# 512  LP002643    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#4
#Capping on Outliers

upper_limit = df4['LoanAmount'].mean() + 3*df4['LoanAmount'].std()
lower_limit = df4['LoanAmount'].mean() - 3*df4['LoanAmount'].std()

# %%
#5
#Now, apply the Capping

df4['LoanAmount'] = np.where(
    df4['LoanAmount']>upper_limit,
    upper_limit,
    np.where(
        df4['LoanAmount']<lower_limit,
        lower_limit,
        df4['LoanAmount']
    )
)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_5472/2053210058.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['LoanAmount'] = np.where(

# %%
plt.figure(1)
plt.subplot(121)
df=df.dropna()
sns.distplot(df4['LoanAmount']);

plt.subplot(122)
df4['LoanAmount'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(1)
plt.subplot(121)
df=df.dropna()
sns.distplot(df['LoanAmount']);

plt.subplot(122)
df['LoanAmount'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#1
print("Highest allowed",df4['Loan_Amount_Term'].mean() + 3*df4['Loan_Amount_Term'].std())
print("Lowest allowed",df4['Loan_Amount_Term'].mean() - 3*df4['Loan_Amount_Term'].std())
# Out:
# Highest allowed 532.6169187548364
# Lowest allowed 154.25808124516357

# %%
#2
#Finding the Outliers
df3[(df3['Loan_Amount_Term'] > 531.1416820798499) | (df3['Loan_Amount_Term'] < 156.4093383283133)]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 14   LP001030    Male     Yes          2      Graduate            No
# 68   LP001238    Male     Yes         3+  Not Graduate           Yes
# 94   LP001325    Male      No          0  Not Graduate            No
# 133  LP001482    Male     Yes          0      Graduate           Yes
# 242  LP001806    Male      No          0      Graduate            No
# 262  LP001870  Female      No          1      Graduate            No
# 495  LP002586  Female     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 14            1299.0             1086.0        17.0             120.0
# 68            7100.0                0.0       125.0              60.0
# 94            3620.0                0.0        25.0             120.0
# 133           3459.0                0.0        25.0             120.0
# ...

# %%
#3
#Trimming of Outliers

df5 = df4[(df4['Loan_Amount_Term'] < 531.1416820798499) & (df4['Loan_Amount_Term'] > 156.4093383283133)]
df5
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 508  LP002626    Male     Yes          0      Graduate           Yes
# 509  LP002634  Female      No          1      Graduate            No
# 510  LP002637    Male      No          0  Not Graduate            No
# 511  LP002640    Male     Yes          1      Graduate            No
# 512  LP002643    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#4
#Capping on Outliers

upper_limit = df5['Loan_Amount_Term'].mean() + 3*df5['Loan_Amount_Term'].std()
lower_limit = df5['Loan_Amount_Term'].mean() - 3*df5['Loan_Amount_Term'].std()

# %%
#5
#Now, apply the Capping

df5['Loan_Amount_Term'] = np.where(
    df5['Loan_Amount_Term']>upper_limit,
    upper_limit,
    np.where(
        df5['Loan_Amount_Term']<lower_limit,
        lower_limit,
        df5['Loan_Amount_Term']
    )
)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_5472/3890131846.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['Loan_Amount_Term'] = np.where(

# %%
plt.figure(1)
plt.subplot(121)
df=df.dropna()
sns.distplot(df5['Loan_Amount_Term']);

plt.subplot(122)
df5['Loan_Amount_Term'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(1)
plt.subplot(121)
df=df.dropna()
sns.distplot(df['Loan_Amount_Term']);

plt.subplot(122)
df['Loan_Amount_Term'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#1
print("Highest allowed",df5['Credit_History'].mean() + 3*df5['Credit_History'].std())
print("Lowest allowed",df5['Credit_History'].mean() - 3*df5['Credit_History'].std())
# Out:
# Highest allowed 1.9035765536924056
# Lowest allowed -0.18474366244572127

# %%
#2
#Finding the Outliers
df5[(df5['Credit_History'] > 1.908290189482961) | (df5['Credit_History'] < -0.19400447519724662)]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
#3
#Trimming of Outliers

df6 = df5[(df5['Credit_History'] < 1.908290189482961) & (df5['Credit_History'] > -0.19400447519724662)]
df6
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 508  LP002626    Male     Yes          0      Graduate           Yes
# 509  LP002634  Female      No          1      Graduate            No
# 510  LP002637    Male      No          0  Not Graduate            No
# 511  LP002640    Male     Yes          1      Graduate            No
# 512  LP002643    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#4
#Capping on Outliers

upper_limit = df6['Credit_History'].mean() + 3*df6['Credit_History'].std()
lower_limit = df6['Credit_History'].mean() - 3*df6['Credit_History'].std()

# %%
#5
#Now, apply the Capping

df6['Credit_History'] = np.where(
    df6['Credit_History']>upper_limit,
    upper_limit,
    np.where(
        df6['Credit_History']<lower_limit,
        lower_limit,
        df6['Credit_History']
    )
)

# %%
plt.figure(1)
plt.subplot(121)
df=df.dropna()
sns.distplot(df6['Credit_History']);

plt.subplot(122)
df6['Credit_History'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(1)
plt.subplot(121)
df=df.dropna()
sns.distplot(df['Credit_History']);

plt.subplot(122)
df['Credit_History'].plot.box(figsize=(16,5))

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df6.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       377.000000         377.000000  377.000000        377.000000
# mean       4710.729689        1368.720413  134.719594        348.986742
# std        2876.742142        1572.473674   54.814572         50.211113
# min         150.000000           0.000000   30.000000        190.285782
# 25%        2876.000000           0.000000  100.000000        360.000000
# 50%        3858.000000        1210.000000  126.000000        360.000000
# 75%        5649.000000        2209.000000  160.000000        360.000000
# max       14660.909263        6433.535128  301.057389        480.000000
#
#        Credit_History
# count      377.000000
# mean         0.859416
# std          0.348053
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# ## feature extraction and feature tunning

# %%
df6['Total_income'] = df6['ApplicantIncome']+df6['CoapplicantIncome']

# %%
df6.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1           4583.0             1508.0       128.0             360.0
# 2           3000.0                0.0        66.0             360.0
# 3           2583.0             2358.0       120.0             360.0
# 4           6000.0                0.0       141.0             360.0
# 5           5417.0             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_income
# 1             1.0         Rural           N        6091.0
# ...

# %%
df6['ApplicantIncomeLog'] = np.log(df6['ApplicantIncome'])

# %%
sns.distplot(df6.ApplicantIncomeLog)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ApplicantIncomeLog', ylabel='Density'>

# %%
df6['CoapplicantIncomeLog'] = np.log(df6['CoapplicantIncome'])
sns.distplot(df6["ApplicantIncomeLog"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ApplicantIncomeLog', ylabel='Density'>

# %%
df6['LoanAmountLog'] = np.log(df6['LoanAmount'])
sns.distplot(df6["LoanAmountLog"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LoanAmountLog', ylabel='Density'>

# %%
df6['Loan_Amount_Term_Log'] = np.log(df6['Loan_Amount_Term'])
sns.distplot(df6["Loan_Amount_Term_Log"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Loan_Amount_Term_Log', ylabel='Density'>

# %%
df6['Total_Income_Log'] = np.log(df6['Total_income'])
sns.distplot(df6["Total_Income_Log"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total_Income_Log', ylabel='Density'>

# %%
df6.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1           4583.0             1508.0       128.0             360.0
# 2           3000.0                0.0        66.0             360.0
# 3           2583.0             2358.0       120.0             360.0
# 4           6000.0                0.0       141.0             360.0
# 5           5417.0             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_income  ApplicantIncomeLog  \
# ...

# %%
cols = ['ApplicantIncome', 'CoapplicantIncome', "LoanAmount", "Loan_Amount_Term", "Total_income", 'Loan_ID', 'CoapplicantIncomeLog']
df6 = df6.drop(columns=cols, axis=1)

# %%
df6.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
# 5   Male     Yes          2      Graduate           Yes             1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 1         Rural           N            8.430109       4.852030
# 2         Urban           Y            8.006368       4.189655
# 3         Urban           Y            7.856707       4.787492
# 4         Urban           Y            8.699515       4.948760
# 5         Urban           Y            8.597297       5.587249
#
#    Loan_Amount_Term_Log  Total_Income_Log
# 1              5.886104          8.714568
# 2              5.886104          8.006368
# ...

# %%
df6.Loan_Status.value_counts()
# Out:
# Y    263
# N    114
# Name: Loan_Status, dtype: int64

# %%
df6.Education.value_counts()
# Out:
# Graduate        299
# Not Graduate     78
# Name: Education, dtype: int64

# %%
df6.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
# 5   Male     Yes          2      Graduate           Yes             1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 1         Rural           N            8.430109       4.852030
# 2         Urban           Y            8.006368       4.189655
# 3         Urban           Y            7.856707       4.787492
# 4         Urban           Y            8.699515       4.948760
# 5         Urban           Y            8.597297       5.587249
#
#    Loan_Amount_Term_Log  Total_Income_Log
# 1              5.886104          8.714568
# 2              5.886104          8.006368
# ...

# %%
d1 = pd.get_dummies(df6['Gender'], drop_first= True)
d2 = pd.get_dummies(df6['Married'], drop_first= True)
d3 = pd.get_dummies(df6['Dependents'], drop_first= True)
d4 = pd.get_dummies(df6['Education'], drop_first= True)
d5 = pd.get_dummies(df6['Self_Employed'], drop_first= True)
d6 = pd.get_dummies(df6['Property_Area'], drop_first= True)



df11 = pd.concat([df6, d1, d2, d3, d4, d5, d6], axis = 1)
df6=df11

cols = ['Gender', 'Married', "Dependents", "Education", "Self_Employed", 'Property_Area']
df6 = df6.drop(columns=cols, axis=1)

# %%
df6
# Out:
#      Credit_History Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 1               1.0           N            8.430109       4.852030
# 2               1.0           Y            8.006368       4.189655
# 3               1.0           Y            7.856707       4.787492
# 4               1.0           Y            8.699515       4.948760
# 5               1.0           Y            8.597297       5.587249
# ..              ...         ...                 ...            ...
# 508             1.0           Y            7.815611       5.236442
# 509             1.0           Y            9.492658       3.688879
# 510             1.0           N            8.188133       4.605170
# 511             1.0           Y            8.710290       5.521461
# 512             1.0           Y            8.096513       4.997212
#
#      Loan_Amount_Term_Log  Total_Income_Log  Male  Yes  1  2  3+  \
# 1                5.886104          8.714568     1    1  1  0   0
# ...

# %%
df6.describe()
# Out:
#        Credit_History  ApplicantIncomeLog  LoanAmountLog  \
# count      377.000000          377.000000     377.000000
# mean         0.859416            8.303686       4.820463
# std          0.348053            0.554916       0.417314
# min          0.000000            5.010635       3.401197
# 25%          1.000000            7.964156       4.605170
# 50%          1.000000            8.257904       4.836282
# 75%          1.000000            8.639234       5.075174
# max          1.000000            9.592940       5.707301
#
#        Loan_Amount_Term_Log  Total_Income_Log        Male         Yes  \
# count            377.000000        377.000000  377.000000  377.000000
# mean               5.841437          8.610202    0.816976    0.631300
# std                0.177811          0.446092    0.387200    0.483094
# min                5.248527          7.273786    0.000000    0.000000
# 25%                5.886104          8.333270    1.000000    0.000000
# ...

# %%
df6.head()
# Out:
#    Credit_History Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 1             1.0           N            8.430109       4.852030
# 2             1.0           Y            8.006368       4.189655
# 3             1.0           Y            7.856707       4.787492
# 4             1.0           Y            8.699515       4.948760
# 5             1.0           Y            8.597297       5.587249
#
#    Loan_Amount_Term_Log  Total_Income_Log  Male  Yes  1  2  3+  Not Graduate  \
# 1              5.886104          8.714568     1    1  1  0   0             0
# 2              5.886104          8.006368     1    1  0  0   0             0
# 3              5.886104          8.505323     1    1  0  0   0             1
# 4              5.886104          8.699515     1    0  0  0   0             0
# 5              5.886104          9.170872     1    1  0  1   0             0
#
#    Yes  Semiurban  Urban
# 1    0          0      0
# 2    1          0      1
# 3    0          0      1
# ...

# %%
# specify input and output attributes
x = df6.drop(columns=['Loan_Status'], axis=1)
y = df6['Loan_Status']

# %%
x
# Out:
#      Credit_History  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  \
# 1               1.0            8.430109       4.852030              5.886104
# 2               1.0            8.006368       4.189655              5.886104
# 3               1.0            7.856707       4.787492              5.886104
# 4               1.0            8.699515       4.948760              5.886104
# 5               1.0            8.597297       5.587249              5.886104
# ..              ...                 ...            ...                   ...
# 508             1.0            7.815611       5.236442              5.886104
# 509             1.0            9.492658       3.688879              5.886104
# 510             1.0            8.188133       4.605170              5.886104
# 511             1.0            8.710290       5.521461              5.886104
# 512             1.0            8.096513       4.997212              5.886104
#
# ...

# %%
y
# Out:
# 1      N
# 2      Y
# 3      Y
# 4      Y
# 5      Y
#       ..
# 508    Y
# 509    Y
# 510    N
# 511    Y
# 512    Y
# Name: Loan_Status, Length: 377, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
x_train.head()
# Out:
#      Credit_History  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  \
# 229             1.0            8.764053       5.298317              5.886104
# 283             1.0            7.501634       3.988984              5.886104
# 404             1.0            8.914761       5.267858              5.886104
# 78              0.0            8.060540       5.192957              5.703782
# 238             1.0            8.245909       4.718499              5.886104
#
#      Total_Income_Log  Male  Yes  1  2  3+  Not Graduate  Yes  Semiurban  \
# 229          8.764053     1    0  0  0   0             0    1          0
# 283          8.153925     0    0  0  0   0             0    0          0
# 404          8.914761     0    0  0  0   0             0    1          0
# 78           8.877242     1    1  0  0   1             0    0          1
# 238          8.245909     0    0  1  0   0             0    0          0
#
#      Urban
# 229      0
# 283      1
# 404      0
# 78       0
# ...

# %%
y_test.head()
# Out:
# 391    Y
# 353    N
# 358    N
# 200    Y
# 72     Y
# Name: Loan_Status, dtype: object

# %%
#

# %%
# randomforest classifier
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print("Accuracy is", model.score(x_test, y_test)*100)
# Out:
# Accuracy is 84.21052631578947

# %%
# decision tree classifier
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier()
model2.fit(x_train, y_train)
print("Accuracy is", model2.score(x_test, y_test)*100)
# Out:
# Accuracy is 71.57894736842105

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression
model3 = LogisticRegression()
model3.fit(x_train, y_train)
print("Accuracy is", model3.score(x_test, y_test)*100)
# Out:
# Accuracy is 87.36842105263159
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# random forest classifier
from sklearn.metrics import confusion_matrix
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[12,  8],
#        [ 9, 66]], dtype=int64)

# %%
import pickle
file=open("model.pkl", 'wb')
pickle.dump(model, file)
